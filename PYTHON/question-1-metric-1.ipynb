# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from Query import Query
from configuration import Configuration
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 0)
conn = pyodbc.connect(Configuration.getConfigValue('database_connection'))
query = Query.getQuery('query_1_1')
query_result = pd.read_sql_query(query,conn)
dataframes = pd.DataFrame(query_result)

if len(dataframes) == 0:
     display("Não há dados para analisar")
else:
    plt.show()
    display("Quantidade de desenvolvedores com code smell em aberto: " + str(len(dataframes)))
    display("Quantidade de code smell aberto: " + str(dataframes["TOTAL"].sum()))
    display(dataframes)
# Out:
# 'Quantidade de desenvolvedores com code smell em aberto: 98'
# 'Quantidade de code smell aberto: 92470'
#     ID_DEVELOPER  TOTAL    EFFORT  INDEX_EFFORT
# 0            110  25706  172513.0          6.71
# 1             12  10752   96653.0          8.99
# 2             13   7276   52342.0          7.19
# 3             83   7066   42209.0          5.97
# 4            112   4582   43584.0          9.51
# 5             42   3452   47933.0         13.89
# 6             81   3369   41852.0         12.42
# 7             17   2583   38672.0         14.97
# 8             36   2388   12140.0          5.08
# 9            100   2294   15154.0          6.61
# 10           120   2030   19879.0          9.79
# 11            24   1991   13109.0          6.58
# 12           114   1732   17534.0         10.12
# 13           109   1423    9017.0          6.34
# 14           113   1400   10679.0          7.63
# 15            90   1307    7186.0          5.50
# ...
